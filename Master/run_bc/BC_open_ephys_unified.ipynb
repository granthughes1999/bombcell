# %% [markdown]
# # Unified Bombcell Runner (Grant)
#
# Single entrypoint replacing batch, single-probe, and NP2.0 rerun notebooks.

# %% [markdown]
# #### General pip install for loading .env

# %%
#!pip install python-dotenv

# %% [markdown]
# #### Imports

# %%
from pathlib import Path
import re
from typing import Any, Dict
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
import sys
import numpy as np
import pandas as pd
import importlib
import subprocess
import os
from dotenv import load_dotenv

plt.rcParams['figure.dpi'] = 120

import bombcell as bc

# ============= Load in configuration and helper functions =============
# Add MOUSE_NAME directory to path
mouse_dir = Path().resolve().parent.parent  # notebook in analyze_bc_results/
print("Notebook:", Path().resolve())
print("Added to sys.path:", mouse_dir)
print("Exists:", mouse_dir.exists())
print("Contents:", [p.name for p in mouse_dir.iterdir()])
sys.path.append(str(Path().resolve().parent))  # adds .../mice/Reach15

print("CWD:", Path().resolve())
print("sys.path[0:5]:", sys.path[0:5])
print("Has Reach15/grant_config.py?:", (Path().resolve().parent / "grant_config.py").exists())
print("Has Reach15/helper_func/grant_config.py?:", (Path().resolve().parent / "helper_func" / "grant_config.py").exists())

import helper_func.prep_data as data_prep
import helper_func.nwb_data_prep as prep
from helper_func.grant_config import load_grant_config
from helper_func.post_analysis_setup import load_post_analysis_context

# Always reload local modules so notebook uses latest patched code.
prep = importlib.reload(prep)
# plots = importlib.reload(plots)

print('pca_data_prep path:', Path(prep.__file__).resolve())
if not hasattr(prep, 'extract_probe_letters'):
    raise AttributeError(
        'Loaded pca_data_prep does not expose extract_probe_letters. '
        'Restart kernel and re-run this cell, then confirm it points to master/pca_data_prep.py.'
    )
# Out:
# ✅ ipywidgets available - interactive GUI ready
# Notebook: C:\Users\user\Documents\github\bombcell\mice\Reach15\run_bc
# Added to sys.path: C:\Users\user\Documents\github\bombcell\mice
# Exists: True
# Contents: ['Reach15']
# CWD: C:\Users\user\Documents\github\bombcell\mice\Reach15\run_bc
# sys.path[0:5]: ['c:\\Users\\user\\anaconda3\\envs\\bombcell\\python311.zip', 'c:\\Users\\user\\anaconda3\\envs\\bombcell\\DLLs', 'c:\\Users\\user\\anaconda3\\envs\\bombcell\\Lib', 'c:\\Users\\user\\anaconda3\\envs\\bombcell', '']
# Has Reach15/grant_config.py?: False
# Has Reach15/helper_func/grant_config.py?: True
# pca_data_prep path: C:\Users\user\Documents\github\bombcell\mice\Reach15\helper_func\nwb_data_prep.py

# %% [markdown]
# ### Load data from .env

# %%
session_data_dic = prep.load_env()
session_data_dic
# Out:
# MOUSE loaded: Reach15
# -- Behavioral Files --
# BEHAVIORAL_FOLDER loaded: grant_reach15_swingDoor-christie
# -- Neuropixels Sessions --
# Session 1: NP_FILE=Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01 DATE=20260129 SESSION=session003 BOMBCELL=bombcell_batch_20260305_1130
# Session 2: NP_FILE=Reach15_20260129_session004_NP_Recording_02_2026-01-29_16-50-32 DATE=20260129 SESSION=session004 BOMBCELL=NA
# Session 3: NP_FILE=Reach15_20260201_session007_NP_Recording_Number02_2026-02-01_18-25-00 DATE=20260201 SESSION=session007 BOMBCELL=bombcell_batch_20260304_1536
# -- Config Defaults --
# RECORDINGS_ROOT loaded: H:/Grant/Neuropixels/Kilosort_Recordings
# OPEN_EPHYS_CONTINUOUS_SUBPATH loaded: Record Node 103/experiment1/recording1/continuous
# STRUCTURE_OEBIN_SUBPATH loaded: Record Node 103/experiment1/recording1/structure.oebin
# NP20_PROBES loaded: A,C,D
# {'MOUSE': 'Reach15',
#  'BEHAVIORAL_FOLDER': 'grant_reach15_swingDoor-christie',
#  'NP_FILE': 'Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01',
#  'NWB_FILE': 'NA',
#  'DATE': '20260129',
#  'SESSION': 'session003',
#  'BOMBCELL': 'bombcell_batch_20260305_1130',
#  'NP_FILE_01': 'Reach15_20260129_session004_NP_Recording_02_2026-01-29_16-50-32',
#  'NWB_FILE_01': 'NA',
#  'DATE_01': '20260129',
#  'SESSION_01': 'session004',
#  'BOMBCELL_01': 'NA',
#  'NP_FILE_02': 'Reach15_20260201_session007_NP_Recording_Number02_2026-02-01_18-25-00',
#  'NWB_FILE_02': 'Reach15_20260201_session007_NP_Recording_Number02_2026-02-01_18-25-00',
#  'DATE_02': '20260201',
#  'SESSION_02': 'session007',
#  'BOMBCELL_02': 'bombcell_batch_20260304_1536',
#  'RECORDINGS_ROOT': 'H:/Grant/Neuropixels/Kilosort_Recordings',
#  'OPEN_EPHYS_CONTINUOUS_SUBPATH': 'Record Node 103/experiment1/recording1/continuous',
#  'STRUCTURE_OEBIN_SUBPATH': 'Record Node 103/experiment1/recording1/structure.oebin',
#  'NP20_PROBES': 'A,C,D',
#  'RESULTS_PATH': '',
#  'RUN_DATES': ''}

# %% [markdown]
# #### =========================================================
# ## STEP 1: Select Neuropixel session to run bombcell on
# #### =========================================================

# %%
SESSION_TO_ANALYZE = 1

MOUSE, BEHAVIORAL_FOLDER, NP_FILE, NWB_FILE, DATE, SESSION, BOMBCELL = prep.session_to_analyze(
                                                                                        session_data_dic['MOUSE'], session_data_dic['BEHAVIORAL_FOLDER'], 
                                                                                        session_data_dic['NP_FILE'],session_data_dic['NWB_FILE'] ,session_data_dic['DATE'], session_data_dic['SESSION'],session_data_dic['BOMBCELL'],
                                                                                        session_data_dic['NP_FILE_01'], session_data_dic['NWB_FILE_01'], session_data_dic['DATE_01'], session_data_dic['SESSION_01'],session_data_dic['BOMBCELL_01'] ,
                                                                                        session_data_dic['NP_FILE_02'], session_data_dic['NWB_FILE_02'], session_data_dic['DATE_02'], session_data_dic['SESSION_02'],session_data_dic['BOMBCELL_02'],
                                                                                        session_selection=SESSION_TO_ANALYZE
                                                                                    )
# Out:
# =============================================
# SESSION SELECTION:
# =============================================
#
# NP_FILE: Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01
# NWB_FILE: NA
# DATE: 20260129
# SESSION: session003
# BEHAVIORAL_FOLDER: grant_reach15_swingDoor-christie
# BOMBCELL: bombcell_batch_20260305_1130

# %% [markdown]
# ### Set and verify bombcell paths using loaded session data from .env

# %%
BOMBCELL_ROOT_FOR_AUTO_BUILD, NWB_PATH, CONFIG_FILE, SESSION_NAME = data_prep.set_bc_paths(session_data_dic, MOUSE, NWB_FILE, NP_FILE, BOMBCELL, BEHAVIORAL_FOLDER, DATE, SESSION, SESSION_TO_ANALYZE)
# Out:
# =============================================
# AUTO-GENERATED SESSION CONFIG
# =============================================
#
# Session selection: 1
# Mouse root: C:\Users\user\Documents\github\bombcell\mice\Reach15
# Recording name: Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01
# Wrote config: C:\Users\user\Documents\github\bombcell\mice\Reach15\configs\grant_recording_config_20260129_session003.json
# All required files/folders found.
# NWB file: H:\NWB_OUT\NA
# Bombcell root folder: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130
# Session config file: C:\Users\user\Documents\github\bombcell\mice\Reach15\configs\grant_recording_config_20260129_session003.json

# %% [markdown]
# #### =======================================
# ## RUN BOMB CELL ANALYSIS
# #### =======================================

# %% [markdown]
# #### Prepare the  cmd file

# %%
# Select run mode and target probe (if applicable)
RUN_MODE = 'batch'  # batch | single_probe | np20_rerun
TARGET_PROBE = 'A'  # only used for single_probe
OVERWRITE = True

runner = Path('run_bombcell_unified.py')
cmd = ['python', str(runner), '--config', str(CONFIG_FILE), '--mode', RUN_MODE]
if RUN_MODE == 'single_probe':
    cmd += ['--target-probe', TARGET_PROBE]
if OVERWRITE:
    cmd.append('--overwrite')

print('Running:', ' '.join(cmd))
# subprocess.run(cmd, check=True)
cmd
# Out:
# Running: python run_bombcell_unified.py --config C:\Users\user\Documents\github\bombcell\mice\Reach15\configs\grant_recording_config_20260129_session003.json --mode batch --overwrite
# ['python',
#  'run_bombcell_unified.py',
#  '--config',
#  'C:\\Users\\user\\Documents\\github\\bombcell\\mice\\Reach15\\configs\\grant_recording_config_20260129_session003.json',
#  '--mode',
#  'batch',
#  '--overwrite']

# %% [markdown]
# ### Start the Bombcell pipeline by running the above command in the terminal.

# %%
# new code
p = subprocess.run(cmd, text=True, capture_output=True)
print("Return code:", p.returncode)
print("\n--- STDOUT ---\n", p.stdout)
print("\n--- STDERR ---\n", p.stderr)
p.check_returncode()  # will raise after printing, if you still want it to
# Out:
# Return code: 0
#
# --- STDOUT ---
#  ✅ ipywidgets available - interactive GUI ready
# Creating run root for mode 'batch' on 20260305 at 1130...
#
# === Probe A (NP2.0 Simplex Lobule & Interposed Nucleus (SIM/IP)) ===
# ks_dir: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_A
# raw_file: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\Record Node 103\experiment1\recording1\continuous\Neuropix-PXI-100.ProbeA\continuous.dat
# meta_file: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\Record Node 103\experiment1\recording1\structure.oebin
# save_path: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_A\bombcell
#
# === BombCell param changes (defaults -> final) ===
# Modified params vs defaults: 3
#   extractRaw: True -> False
#   extractRawNJobs: <MISSING> -> 1
#   ss_min: nan -> nan
# === END PARAM CHANGES ===
#
# 🚀 Starting BombCell quality metrics pipeline...
# 📁 Processing data from: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_A
# Results will be saved to: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_A\bombcell
#
# Loading ephys data...
# Loaded ephys data: 961 units, 26,977,793 spikes
#
# 🔍 Extracting raw waveforms...
#
# ⚙️ Computing quality metrics for 961 units...
#    (Progress bar will appear below)
#
# Saving GUI visualization data...
# GUI visualization data saved to: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_A\bombcell\for_GUI\gui_data.pkl
#    Generated spatial decay fits: 954/961 units
#    Generated amplitude fits: 954/961 units
#
# 🏷️ Classifying units (good/MUA/noise/non-soma)...
#
# Generating summary plots...
# Saved waveforms overlay figure to H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_A\bombcell\bombcell_plots\waveforms_overlay.png
# Sample of quality metrics table:
#   unit_type Original ID # peaks  ... fraction RPVs trough / peak2 peak1 / peak2
# 0       MUA           0   False  ...          True          False         False
# 1     NOISE           1    True  ...         False          False         False
# 2       MUA           2   False  ...          True          False         False
# 3       MUA           3   False  ...          True          False         False
# 4  NON-SOMA           4   False  ...         False           True         False
#
# [5 rows x 14 columns]
# Saved NOISE upset plot to H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_A\bombcell\bombcell_plots\upset_plot_noise.png
# Saved NON-SOMA upset plot to H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_A\bombcell\bombcell_plots\upset_plot_non-soma.png
# Saved MUA upset plot to H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_A\bombcell\bombcell_plots\upset_plot_mua.png
# Saved quality metrics histograms to H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_A\bombcell\bombcell_plots\quality_metrics_histograms.png
#
# Saving results...
# 📁 Saving TSV files to Kilosort directory: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_A
# All expected metrics were successfully saved.
# NOISE       492
# MUA         268
# NON-SOMA    200
# GOOD          1
# Name: count, dtype: int64
#
# === Probe B (NP1.0 Pontine Gray (PG)) ===
# ks_dir: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_B
# raw_file: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\Record Node 103\experiment1\recording1\continuous\Neuropix-PXI-100.ProbeB-AP\continuous.dat
# meta_file: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\Record Node 103\experiment1\recording1\structure.oebin
# save_path: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_B\bombcell
# Applying overrides for probe B: {'maxRPVviolations': 0.2, 'minPresenceRatio': 0.6, 'presenceRatioBinSize': 120, 'tauR_valuesMin': 0.0005, 'tauR_valuesMax': 0.002, 'tauR_valuesStep': 0.0005, 'computeTimeChunks': True, 'deltaTimeChunk': 360}
#
# === BombCell param changes (defaults -> final) ===
# Modified params vs defaults: 8
#   computeTimeChunks: False -> True
#   extractRaw: True -> False
#   extractRawNJobs: <MISSING> -> 1
#   maxRPVviolations: 0.1 -> 0.2
#   minPresenceRatio: 0.7 -> 0.6
#   presenceRatioBinSize: 60 -> 120
#   ss_min: nan -> nan
#   tauR_valuesMin: 0.002 -> 0.0005
# === END PARAM CHANGES ===
#
# 🚀 Starting BombCell quality metrics pipeline...
# 📁 Processing data from: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_B
# Results will be saved to: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_B\bombcell
#
# Loading ephys data...
# Loaded ephys data: 531 units, 21,099,282 spikes
#
# 🔍 Extracting raw waveforms...
# Reordering waveforms from hardware order to site order (383 sites, 384 hardware channels)
#
# ⚙️ Computing quality metrics for 531 units...
#    (Progress bar will appear below)
#
# Saving GUI visualization data...
# GUI visualization data saved to: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_B\bombcell\for_GUI\gui_data.pkl
#    Generated spatial decay fits: 529/531 units
#    Generated amplitude fits: 521/531 units
#
# 🏷️ Classifying units (good/MUA/noise/non-soma)...
#
# Generating summary plots...
# Saved waveforms overlay figure to H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_B\bombcell\bombcell_plots\waveforms_overlay.png
# Sample of quality metrics table:
#   unit_type Original ID # peaks  ... fraction RPVs trough / peak2 peak1 / peak2
# 0      GOOD           0   False  ...         False          False         False
# 1      GOOD           1   False  ...         False          False         False
# 2     NOISE           2   False  ...         False          False         False
# 3     NOISE           3   False  ...         False          False         False
# 4     NOISE           4   False  ...         False          False         False
#
# [5 rows x 14 columns]
# Saved NOISE upset plot to H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_B\bombcell\bombcell_plots\upset_plot_noise.png
# Saved NON-SOMA upset plot to H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_B\bombcell\bombcell_plots\upset_plot_non-soma.png
# Saved MUA upset plot to H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_B\bombcell\bombcell_plots\upset_plot_mua.png
# Saved quality metrics histograms to H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_B\bombcell\bombcell_plots\quality_metrics_histograms.png
#
# Saving results...
# 📁 Saving TSV files to Kilosort directory: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_B
# All expected metrics were successfully saved.
# NON-SOMA    166
# NOISE       153
# GOOD        124
# MUA          88
# Name: count, dtype: int64
#
# === Probe C (NP2.0 Motor Cortex (MoP)) ===
# ks_dir: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_C
# raw_file: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\Record Node 103\experiment1\recording1\continuous\Neuropix-PXI-100.ProbeC\continuous.dat
# meta_file: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\Record Node 103\experiment1\recording1\structure.oebin
# save_path: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_C\bombcell
#
# === BombCell param changes (defaults -> final) ===
# Modified params vs defaults: 3
#   extractRaw: True -> False
#   extractRawNJobs: <MISSING> -> 1
#   ss_min: nan -> nan
# === END PARAM CHANGES ===
#
# 🚀 Starting BombCell quality metrics pipeline...
# 📁 Processing data from: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_C
# Results will be saved to: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_C\bombcell
#
# Loading ephys data...
# Loaded ephys data: 689 units, 11,726,203 spikes
#
# 🔍 Extracting raw waveforms...
#
# ⚙️ Computing quality metrics for 689 units...
#    (Progress bar will appear below)
#
# Saving GUI visualization data...
# GUI visualization data saved to: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_C\bombcell\for_GUI\gui_data.pkl
#    Generated spatial decay fits: 678/689 units
#    Generated amplitude fits: 673/689 units
#
# 🏷️ Classifying units (good/MUA/noise/non-soma)...
#
# Generating summary plots...
# Saved waveforms overlay figure to H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_C\bombcell\bombcell_plots\waveforms_overlay.png
# Sample of quality metrics table:
#   unit_type Original ID # peaks  ... fraction RPVs trough / peak2 peak1 / peak2
# 0     NOISE           0   False  ...         False          False         False
# 1     NOISE           1   False  ...         False          False         False
# 2     NOISE           2    True  ...         False          False         False
# 3     NOISE           3    True  ...         False          False         False
# 4     NOISE           4    True  ...         False          False         False
#
# [5 rows x 14 columns]
# Saved NOISE upset plot to H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_C\bombcell\bombcell_plots\upset_plot_noise.png
# Saved NON-SOMA upset plot to H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_C\bombcell\bombcell_plots\upset_plot_non-soma.png
# Saved MUA upset plot to H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_C\bombcell\bombcell_plots\upset_plot_mua.png
# Saved quality metrics histograms to H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_C\bombcell\bombcell_plots\quality_metrics_histograms.png
#
# Saving results...
# 📁 Saving TSV files to Kilosort directory: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_C
# All expected metrics were successfully saved.
# NOISE       395
# MUA         238
# NON-SOMA     49
# GOOD          7
# Name: count, dtype: int64
#
# === Probe D (NP2.0 The Ventral Anterior-Lateral complex (VA/VL) of the thalamus ) ===
# ks_dir: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_D
# raw_file: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\Record Node 103\experiment1\recording1\continuous\Neuropix-PXI-100.ProbeD\continuous.dat
# meta_file: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\Record Node 103\experiment1\recording1\structure.oebin
# save_path: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_D\bombcell
#
# === BombCell param changes (defaults -> final) ===
# Modified params vs defaults: 3
#   extractRaw: True -> False
#   extractRawNJobs: <MISSING> -> 1
#   ss_min: nan -> nan
# === END PARAM CHANGES ===
#
# 🚀 Starting BombCell quality metrics pipeline...
# 📁 Processing data from: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_D
# Results will be saved to: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_D\bombcell
#
# Loading ephys data...
# Loaded ephys data: 901 units, 52,328,780 spikes
#
# 🔍 Extracting raw waveforms...
#
# ⚙️ Computing quality metrics for 901 units...
#    (Progress bar will appear below)
#
# Saving GUI visualization data...
# GUI visualization data saved to: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_D\bombcell\for_GUI\gui_data.pkl
#    Generated spatial decay fits: 897/901 units
#    Generated amplitude fits: 897/901 units
#
# 🏷️ Classifying units (good/MUA/noise/non-soma)...
#
# Generating summary plots...
# Saved waveforms overlay figure to H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_D\bombcell\bombcell_plots\waveforms_overlay.png
# Sample of quality metrics table:
#   unit_type Original ID # peaks  ... fraction RPVs trough / peak2 peak1 / peak2
# 0       MUA           0   False  ...          True          False         False
# 1  NON-SOMA           1   False  ...         False           True         False
# 2       MUA           2   False  ...          True          False         False
# 3     NOISE           3    True  ...         False          False         False
# 4       MUA           4   False  ...          True          False         False
#
# [5 rows x 14 columns]
# Saved NOISE upset plot to H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_D\bombcell\bombcell_plots\upset_plot_noise.png
# Saved NON-SOMA upset plot to H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_D\bombcell\bombcell_plots\upset_plot_non-soma.png
# Saved MUA upset plot to H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_D\bombcell\bombcell_plots\upset_plot_mua.png
# Saved quality metrics histograms to H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_D\bombcell\bombcell_plots\quality_metrics_histograms.png
#
# Saving results...
# 📁 Saving TSV files to Kilosort directory: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_D
# All expected metrics were successfully saved.
# MUA         522
# NOISE       253
# NON-SOMA     81
# GOOD         45
# Name: count, dtype: int64
#
# === Probe E (NP1.0 Substantia Nigra Pars Reticulata (SnR)) ===
# ks_dir: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_E
# raw_file: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\Record Node 103\experiment1\recording1\continuous\Neuropix-PXI-100.ProbeE-AP\continuous.dat
# meta_file: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\Record Node 103\experiment1\recording1\structure.oebin
# save_path: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_E\bombcell
#
# === BombCell param changes (defaults -> final) ===
# Modified params vs defaults: 3
#   extractRaw: True -> False
#   extractRawNJobs: <MISSING> -> 1
#   ss_min: nan -> nan
# === END PARAM CHANGES ===
#
# 🚀 Starting BombCell quality metrics pipeline...
# 📁 Processing data from: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_E
# Results will be saved to: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_E\bombcell
#
# Loading ephys data...
# Loaded ephys data: 966 units, 27,894,101 spikes
#
# 🔍 Extracting raw waveforms...
# Reordering waveforms from hardware order to site order (383 sites, 384 hardware channels)
#
# ⚙️ Computing quality metrics for 966 units...
#    (Progress bar will appear below)
#
# Saving GUI visualization data...
# GUI visualization data saved to: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_E\bombcell\for_GUI\gui_data.pkl
#    Generated spatial decay fits: 957/966 units
#    Generated amplitude fits: 955/966 units
#
# 🏷️ Classifying units (good/MUA/noise/non-soma)...
#
# Generating summary plots...
# Saved waveforms overlay figure to H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_E\bombcell\bombcell_plots\waveforms_overlay.png
# Sample of quality metrics table:
#   unit_type Original ID # peaks  ... fraction RPVs trough / peak2 peak1 / peak2
# 0     NOISE           0    True  ...         False          False         False
# 1     NOISE           1    True  ...         False          False         False
# 2     NOISE           2   False  ...         False          False         False
# 3  NON-SOMA           3   False  ...         False           True         False
# 4     NOISE           4   False  ...         False          False         False
#
# [5 rows x 14 columns]
# Saved NOISE upset plot to H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_E\bombcell\bombcell_plots\upset_plot_noise.png
# Saved NON-SOMA upset plot to H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_E\bombcell\bombcell_plots\upset_plot_non-soma.png
# Saved MUA upset plot to H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_E\bombcell\bombcell_plots\upset_plot_mua.png
# Saved quality metrics histograms to H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_E\bombcell\bombcell_plots\quality_metrics_histograms.png
#
# Saving results...
# 📁 Saving TSV files to Kilosort directory: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_E
# All expected metrics were successfully saved.
# MUA         488
# NON-SOMA    287
# NOISE       149
# GOOD         42
# Name: count, dtype: int64
#
# === Probe F (NP1.0 Red Nucleus (RN)) ===
# ks_dir: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_F
# raw_file: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\Record Node 103\experiment1\recording1\continuous\Neuropix-PXI-100.ProbeF-AP\continuous.dat
# meta_file: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\Record Node 103\experiment1\recording1\structure.oebin
# save_path: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_F\bombcell
#
# === BombCell param changes (defaults -> final) ===
# Modified params vs defaults: 3
#   extractRaw: True -> False
#   extractRawNJobs: <MISSING> -> 1
#   ss_min: nan -> nan
# === END PARAM CHANGES ===
#
# 🚀 Starting BombCell quality metrics pipeline...
# 📁 Processing data from: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_F
# Results will be saved to: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_F\bombcell
#
# Loading ephys data...
# Loaded ephys data: 1486 units, 58,812,632 spikes
#
# 🔍 Extracting raw waveforms...
# Reordering waveforms from hardware order to site order (383 sites, 384 hardware channels)
#
# ⚙️ Computing quality metrics for 1486 units...
#    (Progress bar will appear below)
#
# Saving GUI visualization data...
# GUI visualization data saved to: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_F\bombcell\for_GUI\gui_data.pkl
#    Generated spatial decay fits: 1462/1486 units
#    Generated amplitude fits: 1451/1486 units
#
# 🏷️ Classifying units (good/MUA/noise/non-soma)...
#
# Generating summary plots...
# Saved waveforms overlay figure to H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_F\bombcell\bombcell_plots\waveforms_overlay.png
# Sample of quality metrics table:
#   unit_type Original ID # peaks  ... fraction RPVs trough / peak2 peak1 / peak2
# 0     NOISE           0   False  ...         False          False         False
# 1     NOISE           1   False  ...         False          False         False
# 2     NOISE           2   False  ...         False          False         False
# 3       MUA           3   False  ...          True          False         False
# 4       MUA           4   False  ...          True          False         False
#
# [5 rows x 14 columns]
# Saved NOISE upset plot to H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_F\bombcell\bombcell_plots\upset_plot_noise.png
# Saved NON-SOMA upset plot to H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_F\bombcell\bombcell_plots\upset_plot_non-soma.png
# Saved MUA upset plot to H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_F\bombcell\bombcell_plots\upset_plot_mua.png
# Saved quality metrics histograms to H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_F\bombcell\bombcell_plots\quality_metrics_histograms.png
#
# Saving results...
# 📁 Saving TSV files to Kilosort directory: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_F
# All expected metrics were successfully saved.
# MUA         653
# NON-SOMA    640
# NOISE       148
# GOOD         45
# Name: count, dtype: int64
#
# Export complete: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130
#
#
# --- STDERR ---
#
# 0it [00:00, ?it/s][Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.0s
#
# 1it [00:00,  9.80it/s]
# 2it [00:00,  9.57it/s][Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.3s
#
# 4it [00:00,  9.54it/s]
# 6it [00:00, 10.71it/s][Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:    0.6s
#
# 8it [00:00, 11.32it/s]
# 10it [00:00, 11.81it/s][Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:    1.0s
#
# 12it [00:01, 12.15it/s]
# 14it [00:01, 12.30it/s]
# 16it [00:01, 12.33it/s][Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    1.4s
#
# 18it [00:01, 12.40it/s]
# 20it [00:01, 12.24it/s]
# 22it [00:01, 11.87it/s][Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    1.9s
#
# 24it [00:02, 11.96it/s]
# 26it [00:02, 11.88it/s]
# 28it [00:02, 11.72it/s]
# 30it [00:02, 11.87it/s][Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed:    2.5s
#
# 32it [00:02, 11.63it/s]
# 34it [00:02, 11.73it/s]
# 36it [00:03, 11.75it/s]
# 38it [00:03, 11.37it/s][Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:    3.3s
#
# 40it [00:03, 11.58it/s]
# 42it [00:03, 11.57it/s]
# 44it [00:03, 11.69it/s]
# 46it [00:03, 11.82it/s]
# 48it [00:04, 11.77it/s][Parallel(n_jobs=-1)]: Done  49 tasks      | elapsed:    4.1s
#
# 50it [00:04, 10.87it/s]
# 52it [00:04, 10.71it/s]
# 54it [00:04, 10.51it/s]
# 56it [00:04, 10.32it/s]
# 58it [00:05,  9.85it/s][Parallel(n_jobs=-1)]: Done  60 tasks      | elapsed:    5.2s
#
# 60it [00:05, 10.29it/s]
# 62it [00:05, 10.61it/s]
# 64it [00:05, 10.96it/s]
# 66it [00:05, 11.29it/s]
# 68it [00:05, 11.24it/s]
# 70it [00:06, 11.52it/s][Parallel(n_jobs=-1)]: Done  71 tasks      | elapsed:    6.1s
#
# 72it [00:06, 11.70it/s]
# 74it [00:06, 11.78it/s]
# 76it [00:06, 11.44it/s]
# 78it [00:06, 11.82it/s]
# 80it [00:07, 11.95it/s]
# 82it [00:07, 11.96it/s][Parallel(n_jobs=-1)]: Done  84 tasks      | elapsed:    7.2s
#
# 84it [00:07, 11.82it/s]
# 86it [00:07, 12.11it/s]
# 88it [00:07, 13.52it/s]
# 90it [00:07, 12.90it/s]
# 92it [00:07, 12.65it/s]
# 94it [00:08, 12.58it/s]
# 96it [00:08, 12.52it/s][Parallel(n_jobs=-1)]: Done  97 tasks      | elapsed:    8.3s
#
# 98it [00:08, 12.51it/s]
# 100it [00:08, 12.39it/s]
# 102it [00:08, 12.08it/s]
# 104it [00:08, 11.91it/s]
# 106it [00:09, 11.86it/s]
# 108it [00:09, 11.85it/s]
# 110it [00:09, 12.11it/s][Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed:    9.5s
#
# 112it [00:09, 12.19it/s]
# 114it [00:09, 12.19it/s]
# 116it [00:09, 12.03it/s]
# 118it [00:10, 11.62it/s]
# 120it [00:10, 11.54it/s]
# 122it [00:10, 11.62it/s]
# 124it [00:10, 11.63it/s]
# 126it [00:10, 11.78it/s][Parallel(n_jobs=-1)]: Done 127 tasks      | elapsed:   10.8s
#
# 128it [00:10, 11.57it/s]
# 130it [00:11, 11.54it/s]
# 132it [00:11, 11.59it/s]
# 134it [00:11, 11.92it/s]
# 136it [00:11, 12.03it/s]
# 138it [00:11, 11.59it/s]
# 140it [00:12, 11.66it/s]
# 142it [00:12, 10.67it/s][Parallel(n_jobs=-1)]: Done 144 tasks      | elapsed:   12.3s
#
# 144it [00:12, 10.98it/s]
# 146it [00:12, 11.51it/s]
# 148it [00:12, 11.58it/s]
# 150it [00:12, 11.16it/s]
# 152it [00:13, 11.41it/s]
# 154it [00:13, 11.68it/s]
# 156it [00:13, 11.33it/s]
# 158it [00:13, 10.68it/s]
# 160it [00:13, 10.58it/s][Parallel(n_jobs=-1)]: Done 161 tasks      | elapsed:   13.8s
#
# 162it [00:14, 10.87it/s]
# 164it [00:14, 12.10it/s]
# 166it [00:14, 11.93it/s]
# 168it [00:14, 11.71it/s]
# 170it [00:14, 11.40it/s]
# 172it [00:14, 11.29it/s]
# 174it [00:15, 10.99it/s]
# 176it [00:15, 10.66it/s]
# 178it [00:15, 10.63it/s][Parallel(n_jobs=-1)]: Done 180 tasks      | elapsed:   15.5s
#
# 180it [00:15, 10.66it/s]
# 182it [00:15, 11.07it/s]
# 184it [00:15, 11.04it/s]
# 186it [00:16, 10.48it/s]
# 188it [00:16, 10.65it/s]
# 190it [00:16, 10.82it/s]
# 192it [00:16, 11.11it/s]
# 194it [00:16, 10.23it/s]
# 196it [00:17, 10.19it/s]
# 198it [00:17, 10.58it/s][Parallel(n_jobs=-1)]: Done 199 tasks      | elapsed:   17.3s
#
# 200it [00:17,  9.83it/s]
# 202it [00:17, 10.25it/s]
# 204it [00:17, 10.72it/s]
# 206it [00:18, 10.56it/s]
# 208it [00:18, 10.62it/s]
# 210it [00:18, 10.56it/s]
# 212it [00:18, 10.58it/s]
# 214it [00:18, 10.77it/s]
# 216it [00:19, 10.72it/s]
# 218it [00:19, 10.84it/s][Parallel(n_jobs=-1)]: Done 220 tasks      | elapsed:   19.3s
#
# 220it [00:19, 10.57it/s]
# 222it [00:19, 12.02it/s]
# 224it [00:19, 11.68it/s]
# 226it [00:19, 11.79it/s]
# 228it [00:20, 11.60it/s]
# 230it [00:20, 11.37it/s]
# 232it [00:20, 11.23it/s]
# 234it [00:20, 11.45it/s]
# 236it [00:20, 11.54it/s]
# 238it [00:20, 11.43it/s]
# 240it [00:21, 11.59it/s][Parallel(n_jobs=-1)]: Done 241 tasks      | elapsed:   21.1s
#
# 242it [00:21, 11.81it/s]
# 244it [00:21, 11.49it/s]
# 246it [00:21, 11.65it/s]
# 248it [00:21, 11.70it/s]
# 250it [00:21, 11.70it/s]
# 252it [00:22, 11.76it/s]
# 254it [00:22, 11.96it/s]
# 256it [00:22, 12.08it/s]
# 258it [00:22, 12.15it/s]
# 260it [00:22, 12.23it/s]
# 262it [00:22, 12.23it/s][Parallel(n_jobs=-1)]: Done 264 tasks      | elapsed:   23.0s
#
# 264it [00:23, 12.25it/s]
# 266it [00:23, 12.19it/s]
# 268it [00:23, 11.72it/s]
# 270it [00:23, 11.91it/s]
# 272it [00:23, 11.61it/s]
# 274it [00:23, 11.41it/s]
# 276it [00:24, 11.28it/s]
# 278it [00:24, 11.50it/s]
# 280it [00:24, 11.14it/s]
# 282it [00:24, 11.26it/s]
# 284it [00:24, 11.37it/s]
# 286it [00:25, 11.48it/s][Parallel(n_jobs=-1)]: Done 287 tasks      | elapsed:   25.0s
#
# 288it [00:25, 11.61it/s]
# 290it [00:25, 11.53it/s]
# 292it [00:25, 11.66it/s]
# 294it [00:25, 11.91it/s]
# 296it [00:25, 11.84it/s]
# 298it [00:26, 11.80it/s]
# 300it [00:26, 11.65it/s]
# 302it [00:26, 11.67it/s]
# 304it [00:26, 11.64it/s]
# 306it [00:26, 11.85it/s]
# 308it [00:26, 11.82it/s]
# 310it [00:27, 11.72it/s][Parallel(n_jobs=-1)]: Done 312 tasks      | elapsed:   27.1s
#
# 312it [00:27, 11.72it/s]
# 314it [00:27, 11.76it/s]
# 316it [00:27, 12.25it/s]
# 318it [00:27, 12.01it/s]
# 320it [00:27, 11.70it/s]
# 322it [00:28, 11.80it/s]
# 324it [00:28, 11.75it/s]
# 326it [00:28, 11.73it/s]
# 328it [00:28, 11.67it/s]
# 330it [00:28, 11.52it/s]
# 332it [00:28, 11.56it/s]
# 334it [00:29, 11.59it/s]
# 336it [00:29, 11.58it/s][Parallel(n_jobs=-1)]: Done 337 tasks      | elapsed:   29.3s
#
# 338it [00:29, 11.68it/s]
# 340it [00:29, 12.93it/s]
# 342it [00:29, 14.26it/s]
# 344it [00:29, 12.64it/s]
# 346it [00:30, 12.12it/s]
# 348it [00:30, 11.96it/s]
# 350it [00:30, 11.76it/s]
# 352it [00:30, 11.66it/s]
# 354it [00:30, 11.65it/s]
# 356it [00:30, 11.42it/s]
# 358it [00:31, 11.43it/s]
# 360it [00:31, 11.55it/s]
# 362it [00:31, 11.70it/s][Parallel(n_jobs=-1)]: Done 364 tasks      | elapsed:   31.5s
#
# 364it [00:31, 11.78it/s]
# 366it [00:31, 11.75it/s]
# 368it [00:31, 11.96it/s]
# 370it [00:32, 12.26it/s]
# 372it [00:32, 12.04it/s]
# 374it [00:32, 11.91it/s]
# 376it [00:32, 11.94it/s]
# 378it [00:32, 12.00it/s]
# 380it [00:32, 11.48it/s]
# 382it [00:33, 12.21it/s]
# 384it [00:33, 11.06it/s]
# 386it [00:33, 10.54it/s]
# 388it [00:33, 10.91it/s]
# 390it [00:33, 11.27it/s][Parallel(n_jobs=-1)]: Done 391 tasks      | elapsed:   33.9s
#
# 392it [00:34, 11.15it/s]
# 394it [00:34, 11.26it/s]
# 396it [00:34, 11.27it/s]
# 398it [00:34, 11.44it/s]
# 400it [00:34, 11.25it/s]
# 402it [00:34, 11.19it/s]
# 404it [00:35, 11.30it/s]
# 406it [00:35, 11.39it/s]
# 408it [00:35, 11.43it/s]
# 410it [00:35, 11.99it/s]
# 412it [00:35, 12.00it/s]
# 414it [00:35, 11.88it/s]
# 416it [00:36, 11.73it/s]
# 418it [00:36, 11.72it/s][Parallel(n_jobs=-1)]: Done 420 tasks      | elapsed:   36.3s
#
# 420it [00:36, 11.71it/s]
# 422it [00:36, 11.65it/s]
# 424it [00:36, 11.60it/s]
# 426it [00:36, 11.56it/s]
# 428it [00:37, 11.48it/s]
# 430it [00:37, 11.57it/s]
# 432it [00:37, 11.21it/s]
# 434it [00:37, 11.11it/s]
# 436it [00:37, 11.21it/s]
# 438it [00:38, 10.69it/s]
# 440it [00:38, 10.94it/s]
# 442it [00:38, 11.45it/s]
# 444it [00:38, 11.43it/s]
# 446it [00:38, 10.87it/s]
# 448it [00:38, 10.64it/s][Parallel(n_jobs=-1)]: Done 449 tasks      | elapsed:   39.0s
#
# 450it [00:39, 10.94it/s]
# 452it [00:39, 10.69it/s]
# 454it [00:39, 10.65it/s]
# 456it [00:39, 10.84it/s]
# 458it [00:39, 10.94it/s]
# 460it [00:40, 10.47it/s]
# 462it [00:40, 10.71it/s]
# 464it [00:40, 10.93it/s]
# 466it [00:40, 12.01it/s]
# 468it [00:40, 11.95it/s]
# 470it [00:40, 11.86it/s]
# 472it [00:41, 11.61it/s]
# 474it [00:41, 11.60it/s]
# 476it [00:41, 11.59it/s]
# 478it [00:41, 11.35it/s][Parallel(n_jobs=-1)]: Done 480 tasks      | elapsed:   41.7s
#
# 480it [00:41, 11.26it/s]
# 482it [00:41, 11.38it/s]
# 484it [00:42, 11.42it/s]
# 486it [00:42, 11.48it/s]
# 488it [00:42, 11.41it/s]
# 490it [00:42, 11.40it/s]
# 492it [00:42, 11.42it/s]
# 494it [00:43, 11.45it/s]
# 496it [00:43, 11.61it/s]
# 498it [00:43, 11.70it/s]
# 500it [00:43, 11.50it/s]
# 502it [00:43, 11.44it/s]
# 504it [00:43, 11.56it/s]
# 506it [00:44, 11.56it/s]
# 508it [00:44, 11.80it/s]
# 510it [00:44, 11.62it/s][Parallel(n_jobs=-1)]: Done 511 tasks      | elapsed:   44.4s
#
# 512it [00:44, 11.44it/s]
# 514it [00:44, 11.49it/s]
# 516it [00:44, 11.54it/s]
# 518it [00:45, 11.56it/s]
# 520it [00:45, 11.70it/s]
# 522it [00:45, 12.18it/s]
# 524it [00:45, 12.52it/s]
# 526it [00:45, 12.46it/s]
# 528it [00:45, 12.48it/s]
# 530it [00:46, 12.56it/s]
# 532it [00:46, 11.72it/s]
# 534it [00:46, 11.55it/s]
# 536it [00:46, 11.62it/s]
# 538it [00:46, 11.40it/s]
# 540it [00:46, 11.49it/s]
# 542it [00:47, 11.68it/s][Parallel(n_jobs=-1)]: Done 544 tasks      | elapsed:   47.2s
#
# 544it [00:47, 11.85it/s]
# 546it [00:47, 11.83it/s]
# 548it [00:47, 11.50it/s]
# 550it [00:47, 11.53it/s]
# 552it [00:47, 11.42it/s]
# 554it [00:48, 11.44it/s]
# 556it [00:48, 12.60it/s]
# 558it [00:48, 12.77it/s]
# 560it [00:48, 12.36it/s]
# 562it [00:48, 12.08it/s]
# 564it [00:48, 12.03it/s]
# 566it [00:49, 12.14it/s]
# 568it [00:49, 12.32it/s]
# 570it [00:49, 12.20it/s]
# 572it [00:49, 12.09it/s]
# 574it [00:49, 12.12it/s]
# 576it [00:49, 11.99it/s][Parallel(n_jobs=-1)]: Done 577 tasks      | elapsed:   49.9s
#
# 578it [00:50, 11.87it/s]
# 580it [00:50, 11.45it/s]
# 582it [00:50, 11.42it/s]
# 584it [00:50, 11.15it/s]
# 586it [00:50, 11.18it/s]
# 588it [00:50, 12.64it/s]
# 590it [00:51, 12.26it/s]
# 592it [00:51, 12.14it/s]
# 594it [00:51, 12.03it/s]
# 596it [00:51, 11.59it/s]
# 598it [00:51, 11.67it/s]
# 600it [00:51, 11.68it/s]
# 602it [00:52, 11.81it/s]
# 604it [00:52, 11.58it/s]
# 606it [00:52, 11.62it/s]
# 608it [00:52, 11.75it/s]
# 610it [00:52, 11.80it/s][Parallel(n_jobs=-1)]: Done 612 tasks      | elapsed:   52.9s
#
# 612it [00:53, 11.75it/s]
# 614it [00:53, 11.77it/s]
# 616it [00:53, 11.72it/s]
# 618it [00:53, 11.56it/s]
# 620it [00:53, 11.25it/s]
# 622it [00:53, 11.44it/s]
# 624it [00:54, 11.79it/s]
# 626it [00:54, 11.97it/s]
# 628it [00:54, 11.99it/s]
# 630it [00:54, 12.26it/s]
# 632it [00:54, 11.99it/s]
# 634it [00:54, 11.99it/s]
# 636it [00:55, 12.04it/s]
# 638it [00:55, 12.00it/s]
# 640it [00:55, 12.03it/s]
# 642it [00:55, 12.03it/s]
# 644it [00:55, 11.91it/s]
# 646it [00:55, 11.84it/s][Parallel(n_jobs=-1)]: Done 647 tasks      | elapsed:   55.9s
#
# 648it [00:56, 11.82it/s]
# 650it [00:56, 12.31it/s]
# 652it [00:56, 12.20it/s]
# 654it [00:56, 12.08it/s]
# 656it [00:56, 12.28it/s]
# 658it [00:56, 12.20it/s]
# 660it [00:56, 12.91it/s]
# 662it [00:57, 12.42it/s]
# 664it [00:57, 12.25it/s]
# 666it [00:57, 12.11it/s]
# 668it [00:57, 11.93it/s]
# 670it [00:57, 12.16it/s]
# 672it [00:57, 12.12it/s]
# 674it [00:58, 12.15it/s]
# 677it [00:58, 13.63it/s]
# 679it [00:58, 13.23it/s]
# 681it [00:58, 12.94it/s]
# 683it [00:58, 12.87it/s][Parallel(n_jobs=-1)]: Done 684 tasks      | elapsed:   58.8s
#
# 685it [00:58, 13.06it/s]
# 687it [00:59, 12.63it/s]
# 689it [00:59, 12.45it/s]
# 691it [00:59, 12.96it/s]
# 693it [00:59, 12.63it/s]
# 695it [00:59, 12.28it/s]
# 697it [00:59, 12.08it/s]
# 699it [01:00, 11.52it/s]
# 701it [01:00, 11.75it/s]
# 703it [01:00, 11.76it/s]
# 705it [01:00, 12.25it/s]
# 707it [01:00, 12.03it/s]
# 709it [01:00, 12.25it/s]
# 711it [01:01, 11.74it/s]
# 713it [01:01, 11.06it/s]
# 715it [01:01, 10.79it/s]
# 717it [01:01, 10.61it/s]
# 719it [01:01, 10.22it/s][Parallel(n_jobs=-1)]: Done 721 tasks      | elapsed:  1.0min
#
# 721it [01:02, 10.83it/s]
# 723it [01:02, 10.50it/s]
# 725it [01:02, 10.88it/s]
# 727it [01:02, 10.83it/s]
# 729it [01:02, 10.92it/s]
# 731it [01:02, 11.68it/s]
# 733it [01:03, 11.04it/s]
# 735it [01:03, 11.25it/s]
# 737it [01:03, 11.30it/s]
# 739it [01:03, 10.98it/s]
# 741it [01:03, 11.11it/s]
# 743it [01:04, 11.58it/s]
# 745it [01:04, 11.63it/s]
# 747it [01:04, 11.75it/s]
# 749it [01:04, 11.88it/s]
# 751it [01:04, 11.99it/s]
# 753it [01:04, 12.05it/s]
# 755it [01:05, 12.01it/s]
# 757it [01:05, 11.90it/s]
# 759it [01:05, 11.91it/s][Parallel(n_jobs=-1)]: Done 760 tasks      | elapsed:  1.1min
#
# 761it [01:05, 11.80it/s]
# 763it [01:05, 11.83it/s]
# 765it [01:05, 12.58it/s]
# 767it [01:06, 11.60it/s]
# 769it [01:06, 10.38it/s]
# 771it [01:06, 10.85it/s]
# 773it [01:06, 11.23it/s]
# 775it [01:06, 10.98it/s]
# 777it [01:07, 11.24it/s]
# 779it [01:07, 11.46it/s]
# 781it [01:07, 11.99it/s]
# 783it [01:07, 11.40it/s]
# 785it [01:07, 11.24it/s]
# 787it [01:07, 11.40it/s]
# 789it [01:08, 10.94it/s]
# 791it [01:08, 10.80it/s]
# 793it [01:08, 11.16it/s]
# 795it [01:08, 10.52it/s]
# 797it [01:08, 10.99it/s][Parallel(n_jobs=-1)]: Done 799 tasks      | elapsed:  1.1min
#
# 799it [01:08, 11.19it/s]
# 801it [01:09, 10.93it/s]
# 803it [01:09, 11.27it/s]
# 805it [01:09, 11.54it/s]
# 807it [01:09, 11.58it/s]
# 809it [01:09, 11.29it/s]
# 811it [01:10, 11.38it/s]
# 813it [01:10, 11.85it/s]
# 815it [01:10, 11.21it/s]
# 817it [01:10, 11.46it/s]
# 819it [01:10, 11.63it/s]
# 821it [01:10, 11.76it/s]
# 823it [01:11, 11.72it/s]
# 825it [01:11, 11.83it/s]
# 827it [01:11, 11.78it/s]
# 829it [01:11, 11.28it/s]
# 831it [01:11, 11.10it/s]
# 833it [01:11, 11.32it/s]
# 835it [01:12, 10.95it/s]
# 837it [01:12, 11.18it/s]
# 839it [01:12, 11.01it/s][Parallel(n_jobs=-1)]: Done 840 tasks      | elapsed:  1.2min
#
# 841it [01:12, 11.33it/s]
# 843it [01:12, 11.62it/s]
# 845it [01:12, 11.81it/s]
# 847it [01:13, 12.01it/s]
# 849it [01:13, 12.09it/s]
# 851it [01:13, 12.00it/s]
# 853it [01:13, 11.94it/s]
# 855it [01:13, 13.11it/s]
# 857it [01:13, 12.84it/s]
# 859it [01:14, 12.50it/s]
# 861it [01:14, 12.42it/s]
# 863it [01:14, 11.98it/s]
# 865it [01:14, 11.89it/s]
# 867it [01:14, 11.96it/s]
# 869it [01:14, 12.07it/s]
# 871it [01:15, 12.09it/s]
# 873it [01:15, 12.37it/s]
# 875it [01:15, 12.20it/s]
# 877it [01:15, 12.16it/s]
# 879it [01:15, 11.99it/s][Parallel(n_jobs=-1)]: Done 881 tasks      | elapsed:  1.3min
#
# 881it [01:15, 12.10it/s]
# 883it [01:16, 12.18it/s]
# 885it [01:16, 12.32it/s]
# 887it [01:16, 12.13it/s]
# 889it [01:16, 12.28it/s]
# 891it [01:16, 12.22it/s]
# 893it [01:16, 12.98it/s]
# 895it [01:17, 12.65it/s]
# 897it [01:17, 12.55it/s]
# 899it [01:17, 12.35it/s]
# 901it [01:17, 12.22it/s]
# 903it [01:17, 13.52it/s]
# 905it [01:17, 13.37it/s]
# 907it [01:17, 12.76it/s]
# 909it [01:18, 12.45it/s]
# 911it [01:18, 12.32it/s]
# 913it [01:18, 12.04it/s]
# 915it [01:18, 11.96it/s]
# 917it [01:18, 11.84it/s]
# 919it [01:19, 11.79it/s]
# 921it [01:19, 11.75it/s]
# 923it [01:19, 11.80it/s][Parallel(n_jobs=-1)]: Done 924 tasks      | elapsed:  1.3min
#
# 925it [01:19, 11.81it/s]
# 927it [01:19, 11.90it/s]
# 929it [01:19, 11.80it/s]
# 931it [01:20, 11.05it/s]
# 933it [01:20, 11.22it/s]
# 935it [01:20, 11.24it/s]
# 937it [01:20, 11.65it/s]
# 939it [01:20, 12.05it/s]
# 941it [01:20, 12.22it/s]
# 943it [01:21, 12.28it/s]
# 945it [01:21, 12.21it/s]
# 947it [01:21, 12.08it/s]
# 949it [01:21, 12.01it/s]
# 951it [01:21, 11.81it/s]
# 953it [01:21, 12.04it/s]
# 955it [01:22, 12.26it/s]
# 957it [01:22, 12.35it/s]
# 959it [01:22, 12.31it/s]
# 961it [01:22, 12.37it/s]
# 961it [01:22, 11.65it/s]
# [Parallel(n_jobs=-1)]: Done 961 out of 961 | elapsed:  1.4min finished
#
# Computing bombcell quality metrics:   0%|          | 0/961 units
# Computing bombcell quality metrics:   0%|          | 1/961 units
# Computing bombcell quality metrics:   0%|          | 2/961 units
# Computing bombcell quality metrics:   0%|          | 3/961 units
# Computing bombcell quality metrics:   0%|          | 4/961 units
# Computing bombcell quality metrics:   1%|          | 5/961 units
# Computing bombcell quality metrics:   1%|          | 6/961 units
# Computing bombcell quality metrics:   1%|          | 7/961 units
# Computing bombcell quality metrics:   1%|          | 8/961 units
# Computing bombcell quality metrics:   1%|          | 9/961 units
# Computing bombcell quality metrics:   1%|          | 10/961 units
# Computing bombcell quality metrics:   1%|          | 11/961 units
# Computing bombcell quality metrics:   1%|          | 12/961 units
# Computing bombcell quality metrics:   1%|▏         | 13/961 units
# Computing bombcell quality metrics:   1%|▏         | 14/961 units
# Computing bombcell quality metrics:   2%|▏         | 15/961 units
# Computing bombcell quality metrics:   2%|▏         | 16/961 units
# Computing bombcell quality metrics:   2%|▏         | 17/961 units
# Computing bombcell quality metrics:   2%|▏         | 18/961 units
# Computing bombcell quality metrics:   2%|▏         | 19/961 units
# Computing bombcell quality metrics:   2%|▏         | 20/961 units
# Computing bombcell quality metrics:   2%|▏         | 21/961 units
# Computing bombcell quality metrics:   2%|▏         | 22/961 units
# Computing bombcell quality metrics:   2%|▏         | 23/961 units
# Computing bombcell quality metrics:   2%|▏         | 24/961 units
# Computing bombcell quality metrics:   3%|▎         | 25/961 units
# Computing bombcell quality metrics:   3%|▎         | 26/961 units
# Computing bombcell quality metrics:   3%|▎         | 27/961 units
# Computing bombcell quality metrics:   3%|▎         | 28/961 units
# Computing bombcell quality metrics:   3%|▎         | 29/961 units
# Computing bombcell quality metrics:   3%|▎         | 30/961 units
# Computing bombcell quality metrics:   3%|▎         | 31/961 units
# Computing bombcell quality metrics:   3%|▎         | 32/961 units
# Computing bombcell quality metrics:   3%|▎         | 33/961 units
# Computing bombcell quality metrics:   4%|▎         | 34/961 units
# Computing bombcell quality metrics:   4%|▎         | 35/961 units
# Computing bombcell quality metrics:   4%|▎         | 36/961 units
# Computing bombcell quality metrics:   4%|▍         | 37/961 units
# Computing bombcell quality metrics:   4%|▍         | 38/961 units
# Computing bombcell quality metrics:   4%|▍         | 39/961 units
# Computing bombcell quality metrics:   4%|▍         | 40/961 units
# Computing bombcell quality metrics:   4%|▍         | 41/961 units
# Computing bombcell quality metrics:   4%|▍         | 42/961 units
# Computing bombcell quality metrics:   4%|▍         | 43/961 units
# Computing bombcell quality metrics:   5%|▍         | 44/961 units
# Computing bombcell quality metrics:   5%|▍         | 45/961 units
# Computing bombcell quality metrics:   5%|▍         | 46/961 units
# Computing bombcell quality metrics:   5%|▍         | 47/961 units
# Computing bombcell quality metrics:   5%|▍         | 48/961 units
# Computing bombcell quality metrics:   5%|▌         | 49/961 units
# Computing bombcell quality metrics:   5%|▌         | 50/961 units
# Computing bombcell quality metrics:   5%|▌         | 51/961 units
# Computing bombcell quality metrics:   5%|▌         | 52/961 units
# Computing bombcell quality metrics:   6%|▌         | 53/961 units
# Computing bombcell quality metrics:   6%|▌         | 54/961 units
# Computing bombcell quality metrics:   6%|▌         | 55/961 units
# Computing bombcell quality metrics:   6%|▌         | 56/961 units
# Computing bombcell quality metrics:   6%|▌         | 57/961 units
# Computing bombcell quality metrics:   6%|▌         | 58/961 units
# Computing bombcell quality metrics:   6%|▌         | 59/961 units
# Computing bombcell quality metrics:   6%|▌         | 60/961 units
# Computing bombcell quality metrics:   6%|▋         | 61/961 units
# Computing bombcell quality metrics:   6%|▋         | 62/961 units
# Computing bombcell quality metrics:   7%|▋         | 63/961 units
# Computing bombcell quality metrics:   7%|▋         | 64/961 units
# Computing bombcell quality metrics:   7%|▋         | 65/961 units
# Computing bombcell quality metrics:   7%|▋         | 66/961 units
# Computing bombcell quality metrics:   7%|▋         | 67/961 units
# Computing bombcell quality metrics:   7%|▋         | 68/961 units
# Computing bombcell quality metrics:   7%|▋         | 69/961 units
# Computing bombcell quality metrics:   7%|▋         | 70/961 units
# Computing bombcell quality metrics:   7%|▋         | 71/961 units
# Computing bombcell quality metrics:   7%|▋         | 72/961 units
# Computing bombcell quality metrics:   8%|▊         | 73/961 units
# Computing bombcell quality metrics:   8%|▊         | 74/961 units
# Computing bombcell quality metrics:   8%|▊         | 75/961 units
# Computing bombcell quality metrics:   8%|▊         | 76/961 units
# Computing bombcell quality metrics:   8%|▊         | 77/961 units
# Computing bombcell quality metrics:   8%|▊         | 78/961 units
# Computing bombcell quality metrics:   8%|▊         | 79/961 units
# Computing bombcell quality metrics:   8%|▊         | 80/961 units
# Computing bombcell quality metrics:   8%|▊         | 81/961 units
# Computing bombcell quality metrics:   9%|▊         | 82/961 units
# Computing bombcell quality metrics:   9%|▊         | 83/961 units
# Computing bombcell quality metrics:   9%|▊         | 84/961 units
# Computing bombcell quality metrics:   9%|▉         | 85/961 units
# Computing bombcell quality metrics:   9%|▉         | 86/961 units
# Computing bombcell quality metrics:   9%|▉         | 87/961 units
# Computing bombcell quality metrics:   9%|▉         | 89/961 units
# Computing bombcell quality metrics:   9%|▉         | 90/961 units
# Computing bombcell quality metrics:   9%|▉         | 91/961 units
# Computing bombcell quality metrics:  10%|▉         | 92/961 units
# Computing bombcell quality metrics:  10%|▉         | 93/961 units
# Computing bombcell quality metrics:  10%|▉         | 94/961 units
# Computing bombcell quality metrics:  10%|▉         | 95/961 units
# Computing bombcell quality metrics:  10%|▉         | 96/961 units
# Computing bombcell quality metrics:  10%|█         | 97/961 units
# Computing bombcell quality metrics:  10%|█         | 98/961 units
# Computing bombcell quality metrics:  10%|█         | 99/961 units
# Computing bombcell quality metrics:  10%|█         | 100/961 units
# Computing bombcell quality metrics:  11%|█         | 101/961 units
# Computing bombcell quality metrics:  11%|█         | 102/961 units
# Computing bombcell quality metrics:  11%|█         | 103/961 units
# Computing bombcell quality metrics:  11%|█         | 104/961 units
# Computing bombcell quality metrics:  11%|█         | 105/961 units
# Computing bombcell quality metrics:  11%|█         | 106/961 units
# Computing bombcell quality metrics:  11%|█         | 107/961 units
# Computing bombcell quality metrics:  11%|█         | 108/961 units
# Computing bombcell quality metrics:  11%|█▏        | 109/961 units
# Computing bombcell quality metrics:  11%|█▏        | 110/961 units
# Computing bombcell quality metrics:  12%|█▏        | 111/961 units
# Computing bombcell quality metrics:  12%|█▏        | 112/961 units
# Computing bombcell quality metrics:  12%|█▏        | 113/961 units
# Computing bombcell quality metrics:  12%|█▏        | 114/961 units
# Computing bombcell quality metrics:  12%|█▏        | 115/961 units
# Computing bombcell quality metrics:  12%|█▏        | 116/961 units
# Computing bombcell quality metrics:  12%|█▏        | 117/961 units
# Computing bombcell quality metrics:  12%|█▏        | 118/961 units
# Computing bombcell quality metrics:  12%|█▏        | 119/961 units
# Computing bombcell quality metrics:  12%|█▏        | 120/961 units
# Computing bombcell quality metrics:  13%|█▎        | 121/961 units
# Computing bombcell quality metrics:  13%|█▎        | 122/961 units
# Computing bombcell quality metrics:  13%|█▎        | 123/961 units
# Computing bombcell quality metrics:  13%|█▎        | 124/961 units
# Computing bombcell quality metrics:  13%|█▎        | 125/961 units
# ...
# Computing bombcell quality metrics:  95%|█████████▌| 1419/1486 units
# Computing bombcell quality metrics:  96%|█████████▌| 1420/1486 units
# Computing bombcell quality metrics:  96%|█████████▌| 1421/1486 units
# Computing bombcell quality metrics:  96%|█████████▌| 1422/1486 units
# Computing bombcell quality metrics:  96%|█████████▌| 1423/1486 units
# Computing bombcell quality metrics:  96%|█████████▌| 1424/1486 units
# Computing bombcell quality metrics:  96%|█████████▌| 1425/1486 units
# Computing bombcell quality metrics:  96%|█████████▌| 1426/1486 units
# Computing bombcell quality metrics:  96%|█████████▌| 1427/1486 units
# Computing bombcell quality metrics:  96%|█████████▌| 1428/1486 units
# Computing bombcell quality metrics:  96%|█████████▌| 1429/1486 units
# Computing bombcell quality metrics:  96%|█████████▌| 1430/1486 units
# Computing bombcell quality metrics:  96%|█████████▋| 1431/1486 units
# Computing bombcell quality metrics:  96%|█████████▋| 1432/1486 units
# Computing bombcell quality metrics:  96%|█████████▋| 1433/1486 units
# Computing bombcell quality metrics:  97%|█████████▋| 1434/1486 units
# Computing bombcell quality metrics:  97%|█████████▋| 1435/1486 units
# Computing bombcell quality metrics:  97%|█████████▋| 1436/1486 units
# Computing bombcell quality metrics:  97%|█████████▋| 1437/1486 units
# Computing bombcell quality metrics:  97%|█████████▋| 1438/1486 units
# Computing bombcell quality metrics:  97%|█████████▋| 1439/1486 units
# Computing bombcell quality metrics:  97%|█████████▋| 1440/1486 units
# Computing bombcell quality metrics:  97%|█████████▋| 1441/1486 units
# Computing bombcell quality metrics:  97%|█████████▋| 1442/1486 units
# Computing bombcell quality metrics:  97%|█████████▋| 1443/1486 units
# Computing bombcell quality metrics:  97%|█████████▋| 1444/1486 units
# Computing bombcell quality metrics:  97%|█████████▋| 1445/1486 units
# Computing bombcell quality metrics:  97%|█████████▋| 1446/1486 units
# Computing bombcell quality metrics:  97%|█████████▋| 1447/1486 units
# Computing bombcell quality metrics:  97%|█████████▋| 1448/1486 units
# Computing bombcell quality metrics:  98%|█████████▊| 1449/1486 units
# Computing bombcell quality metrics:  98%|█████████▊| 1450/1486 units
# Computing bombcell quality metrics:  98%|█████████▊| 1451/1486 units
# Computing bombcell quality metrics:  98%|█████████▊| 1452/1486 units
# Computing bombcell quality metrics:  98%|█████████▊| 1453/1486 units
# Computing bombcell quality metrics:  98%|█████████▊| 1454/1486 units
# Computing bombcell quality metrics:  98%|█████████▊| 1455/1486 units
# Computing bombcell quality metrics:  98%|█████████▊| 1456/1486 units
# Computing bombcell quality metrics:  98%|█████████▊| 1457/1486 units
# Computing bombcell quality metrics:  98%|█████████▊| 1458/1486 units
# Computing bombcell quality metrics:  98%|█████████▊| 1459/1486 units
# Computing bombcell quality metrics:  98%|█████████▊| 1460/1486 units
# Computing bombcell quality metrics:  98%|█████████▊| 1461/1486 units
# Computing bombcell quality metrics:  98%|█████████▊| 1462/1486 units
# Computing bombcell quality metrics:  98%|█████████▊| 1463/1486 units
# Computing bombcell quality metrics:  99%|█████████▊| 1464/1486 units
# Computing bombcell quality metrics:  99%|█████████▊| 1465/1486 units
# Computing bombcell quality metrics:  99%|█████████▊| 1466/1486 units
# Computing bombcell quality metrics:  99%|█████████▊| 1467/1486 units
# Computing bombcell quality metrics:  99%|█████████▉| 1468/1486 units
# Computing bombcell quality metrics:  99%|█████████▉| 1469/1486 units
# Computing bombcell quality metrics:  99%|█████████▉| 1470/1486 units
# Computing bombcell quality metrics:  99%|█████████▉| 1471/1486 units
# Computing bombcell quality metrics:  99%|█████████▉| 1472/1486 units
# Computing bombcell quality metrics:  99%|█████████▉| 1473/1486 units
# Computing bombcell quality metrics:  99%|█████████▉| 1474/1486 units
# Computing bombcell quality metrics:  99%|█████████▉| 1475/1486 units
# Computing bombcell quality metrics:  99%|█████████▉| 1476/1486 units
# Computing bombcell quality metrics:  99%|█████████▉| 1477/1486 units
# Computing bombcell quality metrics:  99%|█████████▉| 1478/1486 units
# Computing bombcell quality metrics: 100%|█████████▉| 1479/1486 units
# Computing bombcell quality metrics: 100%|█████████▉| 1480/1486 units
# Computing bombcell quality metrics: 100%|█████████▉| 1481/1486 units
# Computing bombcell quality metrics: 100%|█████████▉| 1482/1486 units
# Computing bombcell quality metrics: 100%|█████████▉| 1483/1486 units
# Computing bombcell quality metrics: 100%|█████████▉| 1484/1486 units
# Computing bombcell quality metrics: 100%|█████████▉| 1485/1486 units
# Computing bombcell quality metrics: 100%|██████████| 1486/1486 units
# Computing bombcell quality metrics: 100%|██████████| 1486/1486 units
# c:\Users\user\anaconda3\envs\bombcell\Lib\site-packages\upsetplot\plotting.py:795: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   styles["linewidth"].fillna(1, inplace=True)
# c:\Users\user\anaconda3\envs\bombcell\Lib\site-packages\upsetplot\plotting.py:796: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   styles["facecolor"].fillna(self._facecolor, inplace=True)
# c:\Users\user\anaconda3\envs\bombcell\Lib\site-packages\upsetplot\plotting.py:797: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   styles["edgecolor"].fillna(styles["facecolor"], inplace=True)
# c:\Users\user\anaconda3\envs\bombcell\Lib\site-packages\upsetplot\plotting.py:798: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   styles["linestyle"].fillna("solid", inplace=True)
# c:\Users\user\anaconda3\envs\bombcell\Lib\site-packages\bombcell\plot_functions.py:435: RuntimeWarning: Could not create noise upset plot due to library compatibility: Invalid RGBA argument: nan
#   warnings.warn(f"Could not create {unit_type_str.lower()} upset plot due to library compatibility: {e}", RuntimeWarning)
# c:\Users\user\anaconda3\envs\bombcell\Lib\site-packages\upsetplot\plotting.py:795: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   styles["linewidth"].fillna(1, inplace=True)
# c:\Users\user\anaconda3\envs\bombcell\Lib\site-packages\upsetplot\plotting.py:796: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   styles["facecolor"].fillna(self._facecolor, inplace=True)
# c:\Users\user\anaconda3\envs\bombcell\Lib\site-packages\upsetplot\plotting.py:797: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   styles["edgecolor"].fillna(styles["facecolor"], inplace=True)
# c:\Users\user\anaconda3\envs\bombcell\Lib\site-packages\upsetplot\plotting.py:798: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   styles["linestyle"].fillna("solid", inplace=True)
# c:\Users\user\anaconda3\envs\bombcell\Lib\site-packages\bombcell\plot_functions.py:435: RuntimeWarning: Could not create non-soma upset plot due to library compatibility: Do not know how to convert 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# Name: linestyles, dtype: object to dashes
#   warnings.warn(f"Could not create {unit_type_str.lower()} upset plot due to library compatibility: {e}", RuntimeWarning)
# c:\Users\user\anaconda3\envs\bombcell\Lib\site-packages\upsetplot\plotting.py:795: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   styles["linewidth"].fillna(1, inplace=True)
# c:\Users\user\anaconda3\envs\bombcell\Lib\site-packages\upsetplot\plotting.py:796: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   styles["facecolor"].fillna(self._facecolor, inplace=True)
# c:\Users\user\anaconda3\envs\bombcell\Lib\site-packages\upsetplot\plotting.py:797: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   styles["edgecolor"].fillna(styles["facecolor"], inplace=True)
# c:\Users\user\anaconda3\envs\bombcell\Lib\site-packages\upsetplot\plotting.py:798: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   styles["linestyle"].fillna("solid", inplace=True)
# c:\Users\user\anaconda3\envs\bombcell\Lib\site-packages\bombcell\plot_functions.py:435: RuntimeWarning: Could not create mua upset plot due to library compatibility: Invalid RGBA argument: nan
#   warnings.warn(f"Could not create {unit_type_str.lower()} upset plot due to library compatibility: {e}", RuntimeWarning)

# %% [markdown]
# ## View Results of BC run

# %% [markdown]
# #### Select BC file to analyze

# %%
bombcell_run = r'H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130'

# %%
from pathlib import Path
import sys
import numpy as np
import pandas as pd
import bombcell as bc

analysis_dir = Path.cwd().resolve()
sys.path.insert(0, str(analysis_dir))
from post_analysis_setup import load_post_analysis_context

ctx = load_post_analysis_context(CONFIG_FILE)

staging_root = bombcell_run
print('staging_root:', staging_root)
probe_letters = list(ctx['probeLetters'])

for TARGET_PROBE in probe_letters:
    ks_dir = Path(staging_root) / f'kilosort4_{TARGET_PROBE}'
    save_path = ks_dir / 'bombcell'

    print('ks_dir:', ks_dir)
    print('save_path:', save_path)

    param, quality_metrics, _ = bc.load_bc_results(str(save_path))
    unit_type, unit_type_string = bc.qm.get_quality_unit_type(param, quality_metrics)
    qm_df = pd.DataFrame(quality_metrics).copy()
    qm_df['bombcell_label'] = unit_type_string
    qm_df['unit_index'] = np.arange(len(qm_df))

    if 'cluster_id' not in qm_df.columns:
        qm_df['cluster_id'] = qm_df['unit_index']

    print('Loaded units:', len(qm_df))
    print(qm_df['bombcell_label'].value_counts(dropna=False))
# Out:
# ✅ ipywidgets available - interactive GUI ready
# staging_root: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130
# ks_dir: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_A
# save_path: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_A\bombcell
# Loaded units: 961
# bombcell_label
# NOISE       492
# MUA         268
# NON-SOMA    200
# GOOD          1
# Name: count, dtype: int64
# ks_dir: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_B
# save_path: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_B\bombcell
# Loaded units: 531
# bombcell_label
# NON-SOMA    166
# NOISE       153
# GOOD        124
# MUA          88
# Name: count, dtype: int64
# ks_dir: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_C
# save_path: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_C\bombcell
# Loaded units: 689
# bombcell_label
# NOISE       395
# MUA         238
# NON-SOMA     49
# GOOD          7
# Name: count, dtype: int64
# ks_dir: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_D
# save_path: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_D\bombcell
# Loaded units: 901
# bombcell_label
# MUA         522
# NOISE       253
# NON-SOMA     81
# GOOD         45
# Name: count, dtype: int64
# ks_dir: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_E
# save_path: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_E\bombcell
# Loaded units: 966
# bombcell_label
# MUA         488
# NON-SOMA    287
# NOISE       149
# GOOD         42
# Name: count, dtype: int64
# ks_dir: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_F
# save_path: H:\Grant\Neuropixels\Kilosort_Recordings\Reach15_20260129_session003_NP_Recording_2026-01-29_14-30-01\bombcell\bombcell_batch_20260305_1130\kilosort4_F\bombcell
# Loaded units: 1486
# bombcell_label
# MUA         653
# NON-SOMA    640
# NOISE       148
# GOOD         45
# Name: count, dtype: int64
